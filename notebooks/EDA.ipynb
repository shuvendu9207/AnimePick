# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/processed/final_merged.csv")
df.head()
# Out:
#    anilist_id   mal_id           title_romaji                   title_english  \
# 0       16498  16498.0     Shingeki no Kyojin                 Attack on Titan
# 1      101922  38000.0       Kimetsu no Yaiba  Demon Slayer: Kimetsu no Yaiba
# 2        1535   1535.0             DEATH NOTE                      Death Note
# 3      113415  40748.0         Jujutsu Kaisen                  JUJUTSU KAISEN
# 4       21459  31964.0  Boku no Hero Academia                My Hero Academia
#
#   title_native                                        description  episodes  \
# 0        進撃の巨人  Several hundred years ago, humans were nearly ...      25.0
# 1         鬼滅の刃  It is the Taisho Period in Japan. Tanjiro, a k...      26.0
# 2   DEATH NOTE  Light Yagami is a genius high school student w...      37.0
# 3         呪術廻戦  A boy fights... for "the right death."<br>\n<b...      24.0
# 4  僕のヒーローアカデミア  What would the world be like if 80 percent of ...      13.0
#
# ...

# %%
df.describe()
# Out:
#           anilist_id        mal_id     episodes     popularity  averageScore  \
# count    1500.000000   1499.000000  1493.000000    1500.000000   1495.000000
# mean    72250.290000  30723.981321    16.085733  129972.471333     73.772575
# std     60717.620932  17669.012279    27.265144  116572.770874      7.555270
# min         1.000000      1.000000     1.000000   44278.000000     45.000000
# 25%     14747.000000  14745.000000    12.000000   59182.500000     69.000000
# 50%     97917.500000  34498.000000    12.000000   87886.000000     74.000000
# 75%    125059.500000  43382.000000    13.000000  150961.500000     79.000000
# max    189117.000000  61322.000000   500.000000  938026.000000     91.000000
#
#         rating_count   avg_rating
# count    1500.000000  1500.000000
# mean   129972.471333     7.369333
# std    116572.770874     0.766619
# min     44278.000000     4.500000
# 25%     59182.500000     6.900000
# 50%     87886.000000     7.400000
# ...

# %%
df["avg_rating"].hist(bins=20, figsize=(8,4))
plt.show()

# %%
df["rating_count"].hist(bins=20, figsize=(8,4))
plt.show()

# %%
sns.scatterplot(data=df, x="rating_count", y="avg_rating")
plt.show()
